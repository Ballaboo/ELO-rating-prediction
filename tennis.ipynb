# %%
# Import depencies in venv
import pandas as pd
import numpy as np
import os

# %%
# Expand csv path to user 
csv_path = os.path.expanduser('~/Project/tennis/tennis_atp/')

# List to hole append
csv_combine = []

# Loop through 2000-2024
for year in range(2000, 2024):
    file_path = os.path.join(csv_path, f'atp_matches_{year}.csv')
    df = pd.read_csv(file_path)  # This should now work correctly
    csv_combine.append(df)

# Concat akk dataframes
df_concat = pd.concat(csv_combine, ignore_index=True)

# %%
df_concat.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2000-301     Auckland    Hard         32             A      20000110
# 1   2000-301     Auckland    Hard         32             A      20000110
# 2   2000-301     Auckland    Hard         32             A      20000110
# 3   2000-301     Auckland    Hard         32             A      20000110
# 4   2000-301     Auckland    Hard         32             A      20000110
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0          1     103163          1.0          NaN  ...    55.0     39.0
# 1          2     102607          NaN            Q  ...    32.0     25.0
# 2          3     103252          NaN          NaN  ...    33.0     20.0
# 3          4     103507          7.0          NaN  ...    43.0     29.0
# 4          5     102103          NaN            Q  ...    46.0     34.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...

# %%
df_concat.tail()
# Out:
#                              tourney_id                  tourney_name surface  \
# 71825  2023-M-DC-2023-WG2-PO-RSA-LUX-01  Davis Cup WG2 PO: RSA vs LUX     NaN
# 71826  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 71827  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 71828  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 71829  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
#
#        draw_size tourney_level  tourney_date  match_num  winner_id  \
# 71825          4             D      20230204          5     202335
# 71826          4             D      20230203          1     117365
# 71827          4             D      20230203          2     121411
# 71828          4             D      20230203          4     144949
# 71829          4             D      20230203          5     121411
#
#        winner_seed winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  \
# ...
